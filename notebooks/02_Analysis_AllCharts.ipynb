# %% [markdown]
# # 📊 DQN Analysis Notebook
# All charts, heatmaps, comparisons, confusion matrix, and metrics in one place.

# %%
import sys,os,json
sys.path.insert(0,os.path.abspath('..'))
import numpy as np
import matplotlib; matplotlib.use('Agg')
import matplotlib.pyplot as plt
from IPython.display import Image
with open('../logs/training_stats.json') as f: stats=json.load(f)
ep_r=np.array(stats['episode_rewards'])
print(f'Stats loaded: {len(ep_r)} episodes, best={stats["best_reward"]}')

# %% [markdown]
# ## Training Dashboard

# %%
Image('../charts/01_training_dashboard.png')

# %% [markdown]
# ## Reward Distribution

# %%
Image('../charts/02_reward_distribution.png')

# %% [markdown]
# ## Confusion Matrix

# %%
Image('../charts/03_confusion_matrix.png')

# %% [markdown]
# ## Q-Value Heatmap

# %%
Image('../charts/04_q_value_heatmap.png')

# %% [markdown]
# ## Policy Map (State Space)

# %%
Image('../charts/05_policy_map.png')

# %% [markdown]
# ## Algorithm Comparison

# %%
Image('../charts/06_algorithm_comparison.png')

# %% [markdown]
# ## Architecture Diagram

# %%
Image('../charts/07_architecture_diagram.png')

# %% [markdown]
# ## Pretraining Analysis

# %%
Image('../charts/08_pretraining_analysis.png')

# %% [markdown]
# ## State Trajectories

# %%
Image('../charts/09_trajectory.png')

# %% [markdown]
# ## Weight Distribution

# %%
Image('../charts/10_weight_distribution.png')

# %% [markdown]
# ## Hyperparameter Table

# %%
Image('../charts/11_hyperparameter_table.png')

# %% [markdown]
# ## Algorithm Flow

# %%
Image('../charts/12_algorithm_flowchart.png')

# %% [markdown]
# ## Correlation Heatmap

# %%
Image('../charts/13_correlation_heatmap.png')

# %% [markdown]
# ## Replay Buffer

# %%
Image('../charts/14_replay_buffer.png')

# %% [markdown]
# ## Summary Stats

# %%
print('='*50)
print('  TRAINING SUMMARY')
print('='*50)
print(f'  Episodes       : {len(ep_r)}')
print(f'  Total Steps    : {stats["total_steps"]:,}')
print(f'  Best Reward    : {stats["best_reward"]:.1f}')
print(f'  Final Avg-100  : {np.mean(ep_r[-100:]):.1f}')
print(f'  Solve Rate     : {np.mean(ep_r>=475)*100:.1f}%')
print(f'  Train Time     : {stats["elapsed_seconds"]:.0f}s')
print('='*50)
